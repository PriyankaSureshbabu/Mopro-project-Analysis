# %% [markdown]
# # MOPRO PROJECT ANALYSIS
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('C:/Users/priya/OneDrive/Desktop/mopro project/MOPRO_Project_Analysiscsv.csv')
df.head()
# Out:
#    No of Calls       DATE                NAME    PROFESSION License Type  \
# 0            1  1/27/2025       Melissa Young  Healing arts     Business
# 1            2  1/27/2025         Paula akins  Healing arts  Individual
# 2            3  1/27/2025     Timothy colleen     Physician  Individual
# 3            4  1/27/2025  Angela Renee Miner       Massage  Individual
# 4            5  1/27/2025    Eftekhar Arshadi        Dental  Individual
#
#               ISSUE           SOLUTION
# 0  License querries  Referred to board
# 1       Walkthrough            Renewed
# 2      Update email         Registered
# 3      Update email         Registered
# 4       Walkthrough            Renewed

# %%
df.tail()
# Out:
#      No of Calls      DATE                      NAME   PROFESSION  \
# 884          885  5/8/2025              Suzanne Lowe     Pharmacy
# 885          886  5/8/2025            Sharron Pierce      Nursing
# 886          887     45786          Hallie Wit Hoehn  Real Estate
# 887          888     45786  Cynthia Lou Day Pfeiffer  Real Estate
# 888          889     45786           Serena Williams     Pharmacy
#
#     License Type              ISSUE    SOLUTION
# 884  Individual        Update Email  Registered
# 885  Individual      Password reset    Resolved
# 886  Individual   Application issue    Resolved
# 887  Individual   Application issue    Resolved
# 888  Individual        Update Email  Registered

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
sns.pairplot(df, x_vars=['PROFESSION', 'ISSUE'], 
             y_vars='SOLUTION', size=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value?
# My R squared value was 0.204.
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset?
# It was not particularly effective in this case.
# 3. Was your plot of the error terms a bell curve?
# Yes! My plot of the error terms was a bell curve.
